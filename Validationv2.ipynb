# %%
import random
random.seed(122)

import csv
import pandas as pd
import numpy as np
import xgboost as xgb
import time

from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import classification_report, confusion_matrix  
from sklearn import metrics
from sklearn.model_selection import train_test_split

from numpy import loadtxt
from xgboost import XGBClassifier
from xgboost import plot_importance
from xgboost import DMatrix
from matplotlib import pyplot
from math import *

with open('ml_features_201710.csv','rb') as data:
    features = pd.read_csv(data)
    
with open('crg123.csv','rb') as data2:
    features2 = pd.read_csv(data2)
      
   
start = time.time()  

features=features.rename(columns = {'interact':'label'})
features2=features2.rename(columns = {'interact':'label'})

#convert labels to boolean values
features.loc[features['label']=='YES','label']=1
features.loc[features['label']=='NO','label']=0

features2.loc[features2['label']=='YES','label']=1
features2.loc[features2['label']=='NO','label']=0

#shuffle dataframe
features = features.sample(frac=1).reset_index(drop=True)
features2 = features2.sample(frac=1).reset_index(drop=True)

# Labels are the values we want to predict
train_labels = np.array(features['label'])
test_labels = np.array(features2['label'])
# Remove the labels from the features
# axis 1 refers to the columns
train_features= features.drop('label', axis = 1)
test_features= features2.drop('label', axis = 1)
# Saving feature names for later use
feature_list = list(train_features.columns)
# Convert to numpy array
train_features = np.array(train_features)
test_features = np.array(test_features)

#Using Skicit-learn to split data into training and testing sets

# Split the data into training and testing sets
#train_features, test_features, train_labels, test_labels = train_test_split(features, labels, test_size = 0.30, random_state = 42)
end = time.time()

print(round(end - start,2)," seconds elapsed")
# Out:
# (0.44, ' seconds elapsed')

# %%
#Show histogram of each variable 

for myFeature in feature_list:
    print(myFeature)
    pyplot.hist(features[myFeature],'auto' )
    pyplot.title("Training")
    pyplot.show()
    pyplot.title("Validation")
    pyplot.hist(features2[myFeature],'auto',color='orange')
    pyplot.show()
# Out:
# Pathogen_Ala
# Pathogen_Arg
# Pathogen_Asn
# Pathogen_Asp
# Pathogen_Cys
# Pathogen_Gln
# Pathogen_Glu
# Pathogen_Gly
# Pathogen_His
# Pathogen_Ile
# Pathogen_Leu
# Pathogen_Lys
# Pathogen_Met
# Pathogen_Phe
# Pathogen_Pro
# Pathogen_Ser
# Pathogen_Thr
# Pathogen_Trp
# Pathogen_Tyr
# Pathogen_Val
# Host_Ala
# Host_Arg
# Host_Asn
# Host_Asp
# Host_Cys
# Host_Gln
# Host_Glu
# Host_Gly
# Host_His
# Host_Ile
# Host_Leu
# Host_Lys
# Host_Met
# Host_Phe
# Host_Pro
# Host_Ser
# Host_Thr
# Host_Trp
# Host_Tyr
# Host_Val
# GO_Similarity_Score

# %%
#source https://xgboost.readthedocs.io/en/latest/get_started.html
start = time.time()

dtrain = DMatrix(train_features,label=train_labels,feature_names=feature_list)
dtest = DMatrix(test_features,label=test_labels,feature_names=feature_list)
# specify parameters via map
#param = {'max_depth':2, 'eta':1, 'silent':1, 'objective':'binary:logistic' }
param = {'silent':1}
num_round = 100
bst = xgb.train(param, dtrain, num_round)
# make prediction
predictions = bst.predict(dtest)

end = time.time()

print(round(end - start,2)," seconds elapsed")


print(confusion_matrix(test_labels,predictions.round()))  
print(classification_report(test_labels,predictions.round()))  


# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(test_labels,predictions.round()))


# plot feature importance
#refference https://machinelearningmastery.com/feature-importance-and-feature-selection-with-xgboost-in-python/
fig, ax = pyplot.subplots(figsize=(10,20))
plot_importance(bst, ax=ax)
pyplot.show()
# Out:
# (19.7, ' seconds elapsed')
# [[ 97 187]
#  [ 54 175]]
#               precision    recall  f1-score   support
#
#            0       0.64      0.34      0.45       284
#            1       0.48      0.76      0.59       229
#
#    micro avg       0.53      0.53      0.53       513
#    macro avg       0.56      0.55      0.52       513
# weighted avg       0.57      0.53      0.51       513
#
# ('Accuracy:', 0.530214424951267)

# %%
#source https://xgboost.readthedocs.io/en/latest/get_started.html
start = time.time()

dtrain = DMatrix(train_features,label=train_labels,feature_names=feature_list)
dtest = DMatrix(test_features,label=test_labels,feature_names=feature_list)
# specify parameters via map
#param = {'max_depth':2, 'eta':1, 'silent':1, 'objective':'binary:logistic' }
param = {'silent':1}
num_round = 500
bst = xgb.train(param, dtrain, num_round)
# make prediction
predictions = bst.predict(dtest)

end = time.time()

print(round(end - start,2)," seconds elapsed")


print(confusion_matrix(test_labels,predictions.round()))  
print(classification_report(test_labels,predictions.round()))  


# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(test_labels,predictions.round()))


# plot feature importance - 
#code refference https://machinelearningmastery.com/feature-importance-and-feature-selection-with-xgboost-in-python/
# reference https://machinelearningmastery.com/feature-importance-and-feature-selection-with-xgboost-in-python/
fig, ax = pyplot.subplots(figsize=(10,20))
plot_importance(bst, ax=ax)
pyplot.show()
# Out:
# (87.33, ' seconds elapsed')
# [[ 82 202]
#  [ 45 184]]
#               precision    recall  f1-score   support
#
#            0       0.65      0.29      0.40       284
#            1       0.48      0.80      0.60       229
#
#    micro avg       0.52      0.52      0.52       513
#    macro avg       0.56      0.55      0.50       513
# weighted avg       0.57      0.52      0.49       513
#
# ('Accuracy:', 0.5185185185185185)

# %%
#random forest.  Source Link: https://towardsdatascience.com/random-forest-in-python-24d0893d51c0 and https://www.datacamp.com/community/tutorials/random-forests-classifier-python
start = time.time() 

from numpy import loadtxt
from xgboost import XGBClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# Instantiate model with 1000 decision trees  
#-  1 tree had Accuracy:    81.01%. and took 1 sec.
# - 10 trees had Accuracy:  89.27%. and took 10 sec.
# - 100 trees had Accuracy: 90.87%. and took 102 sec.
# - 500 trees had Accuracy: 90.76%. and took 483 sec.
rf = RandomForestRegressor(n_estimators = 100, random_state = 42)
# Train the model on training data
rf.fit(train_features, train_labels);


# Use the forest's predict method on the test data
predictions = rf.predict(test_features)

#calcualte the accuracy
accuracy = sum(predictions.round() == test_labels)/test_labels.size
# Print out the Accuracy
print('Accuracy:', 100*round(accuracy, 4), '%.')

end = time.time()

print(round(end - start,2)," seconds elapsed")


print(confusion_matrix(test_labels,predictions.round()))  
print(classification_report(test_labels,predictions.round()))  


# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(test_labels,predictions.round()))

# Get numerical feature importances
importances = list(rf.feature_importances_)
# List of tuples with variable and importance
feature_importances = [(feature, round(importance, 2)) for feature, importance in zip(feature_list, importances)]
# Sort the feature importances by most important first
feature_importances = sorted(feature_importances, key = lambda x: x[1], reverse = True)
# Print out the feature and importances 
for pair in feature_importances:
    print("Variable: {:20} Importance: {}".format(*pair))
# Out:
# ('Accuracy:', 0.0, '%.')
# (193.99, ' seconds elapsed')
# [[103 181]
#  [ 55 174]]
#               precision    recall  f1-score   support
#
#            0       0.65      0.36      0.47       284
#            1       0.49      0.76      0.60       229
#
#    micro avg       0.54      0.54      0.54       513
#    macro avg       0.57      0.56      0.53       513
# weighted avg       0.58      0.54      0.52       513
#
# ('Accuracy:', 0.5399610136452242)
# Variable: GO_Similarity_Score  Importance: 0.2
# Variable: Host_Arg             Importance: 0.12
# Variable: Host_Ile             Importance: 0.05
# Variable: Host_Asp             Importance: 0.04
# Variable: Host_Cys             Importance: 0.03
# Variable: Host_Glu             Importance: 0.03
# Variable: Host_His             Importance: 0.03
# Variable: Host_Tyr             Importance: 0.03
# Variable: Pathogen_Ala         Importance: 0.02
# Variable: Pathogen_Pro         Importance: 0.02
# Variable: Pathogen_Ser         Importance: 0.02
# Variable: Host_Ala             Importance: 0.02
# Variable: Host_Asn             Importance: 0.02
# Variable: Host_Gln             Importance: 0.02
# Variable: Host_Gly             Importance: 0.02
# Variable: Host_Leu             Importance: 0.02
# Variable: Host_Lys             Importance: 0.02
# Variable: Host_Met             Importance: 0.02
# Variable: Host_Phe             Importance: 0.02
# Variable: Host_Pro             Importance: 0.02
# Variable: Host_Ser             Importance: 0.02
# Variable: Host_Thr             Importance: 0.02
# Variable: Host_Trp             Importance: 0.02
# Variable: Host_Val             Importance: 0.02
# Variable: Pathogen_Arg         Importance: 0.01
# Variable: Pathogen_Asn         Importance: 0.01
# Variable: Pathogen_Asp         Importance: 0.01
# Variable: Pathogen_Cys         Importance: 0.01
# Variable: Pathogen_Gln         Importance: 0.01
# Variable: Pathogen_Glu         Importance: 0.01
# Variable: Pathogen_Gly         Importance: 0.01
# Variable: Pathogen_His         Importance: 0.01
# Variable: Pathogen_Ile         Importance: 0.01
# Variable: Pathogen_Leu         Importance: 0.01
# Variable: Pathogen_Lys         Importance: 0.01
# Variable: Pathogen_Met         Importance: 0.01
# Variable: Pathogen_Phe         Importance: 0.01
# Variable: Pathogen_Thr         Importance: 0.01
# Variable: Pathogen_Trp         Importance: 0.01
# Variable: Pathogen_Tyr         Importance: 0.01
# Variable: Pathogen_Val         Importance: 0.01

# %%
#re-import data without columns that have less than 0.02 from the above feature importance print out

#random forest.  Source Link: https://towardsdatascience.com/random-forest-in-python-24d0893d51c0 and https://www.datacamp.com/community/tutorials/random-forests-classifier-python

with open('ml_features_201710.csv','rb') as data:
    features = pd.read_csv(data)
      
with open('crg123.csv','rb') as data2:
    features2 = pd.read_csv(data2)
    
start = time.time()  

features=features.rename(columns = {'interact':'label'})
features2=features2.rename(columns = {'interact':'label'})

#remove columns 
features=features.drop(['Pathogen_Arg','Pathogen_Asn','Pathogen_Asp','Pathogen_Cys','Pathogen_Gln',
                        'Pathogen_Glu','Pathogen_Gly',
                        'Pathogen_His','Pathogen_Ile','Pathogen_Leu','Pathogen_Lys','Pathogen_Met','Pathogen_Phe','Pathogen_Ser',
                        'Pathogen_Thr','Pathogen_Trp','Pathogen_Tyr','Pathogen_Val'],axis = 1)

features2=features2.drop(['Pathogen_Arg','Pathogen_Asn','Pathogen_Asp','Pathogen_Cys','Pathogen_Gln',
                        'Pathogen_Glu','Pathogen_Gly',
                        'Pathogen_His','Pathogen_Ile','Pathogen_Leu','Pathogen_Lys','Pathogen_Met','Pathogen_Phe','Pathogen_Ser',
                        'Pathogen_Thr','Pathogen_Trp','Pathogen_Tyr','Pathogen_Val'],axis = 1)

#convert labels to boolean values
features.loc[features['label']=='YES','label']=1
features.loc[features['label']=='NO','label']=0

features2.loc[features2['label']=='YES','label']=1
features2.loc[features2['label']=='NO','label']=0

#shuffle dataframe
features = features.sample(frac=1).reset_index(drop=True)
features2 = features2.sample(frac=1).reset_index(drop=True)

# Labels are the values we want to predict
train_labels = np.array(features['label'])
test_labels = np.array(features2['label'])
# Remove the labels from the features
# axis 1 refers to the columns
train_features= features.drop('label', axis = 1)
test_features= features2.drop('label', axis = 1)
# Saving feature names for later use
feature_list = list(train_features.columns)
# Convert to numpy array
train_features = np.array(train_features)
test_features = np.array(test_features)

start = time.time() 




# Instantiate model with 1000 decision trees  
#-  1 tree had Accuracy:    81.91%. and took 1 sec.
# - 10 trees had Accuracy:  88.99%. and took 13 sec.
# - 100 trees had Accuracy: 91.01%. and took 120 sec.
# - 500 trees had Accuracy: 90.76%. and took 483 sec.
rf = RandomForestRegressor(n_estimators = 100, random_state = 42)
# Train the model on training data
rf.fit(train_features, train_labels);


# Use the forest's predict method on the test data
predictions = rf.predict(test_features)

end = time.time()

print(str(round(end - start,2))+" seconds elapsed")


print(confusion_matrix(test_labels,predictions.round()))  
print(classification_report(test_labels,predictions.round()))  


# Model Accuracy, how often is the classifier correct?
print("Accuracy:"+str(metrics.accuracy_score(test_labels,predictions.round())))

# Get numerical feature importances
importances = list(rf.feature_importances_)
# List of tuples with variable and importance
feature_importances = [(feature, round(importance, 2)) for feature, importance in zip(feature_list, importances)]
# Sort the feature importances by most important first
feature_importances = sorted(feature_importances, key = lambda x: x[1], reverse = True)
# Print out the feature and importances 

for pair in feature_importances:
    print("Variable: {:20} Importance: {}".format(*pair))
# Out:
# 125.25 seconds elapsed
# [[104 180]
#  [ 49 180]]
#               precision    recall  f1-score   support
#
#            0       0.68      0.37      0.48       284
#            1       0.50      0.79      0.61       229
#
#    micro avg       0.55      0.55      0.55       513
#    macro avg       0.59      0.58      0.54       513
# weighted avg       0.60      0.55      0.54       513
#
# Accuracy:0.5536062378167641
# Variable: GO_Similarity_Score  Importance: 0.2
# Variable: Host_Arg             Importance: 0.12
# Variable: Host_Ile             Importance: 0.06
# Variable: Host_Asp             Importance: 0.05
# Variable: Pathogen_Ala         Importance: 0.04
# Variable: Pathogen_Pro         Importance: 0.04
# Variable: Host_Cys             Importance: 0.04
# Variable: Host_Tyr             Importance: 0.04
# Variable: Host_Asn             Importance: 0.03
# Variable: Host_Gln             Importance: 0.03
# Variable: Host_Glu             Importance: 0.03
# Variable: Host_Gly             Importance: 0.03
# Variable: Host_His             Importance: 0.03
# Variable: Host_Leu             Importance: 0.03
# Variable: Host_Met             Importance: 0.03
# Variable: Host_Phe             Importance: 0.03
# Variable: Host_Pro             Importance: 0.03
# Variable: Host_Ser             Importance: 0.03
# Variable: Host_Thr             Importance: 0.03
# Variable: Host_Val             Importance: 0.03
# Variable: Host_Ala             Importance: 0.02
# Variable: Host_Lys             Importance: 0.02
# Variable: Host_Trp             Importance: 0.02

# %%
#summary stats
print("Training dataset is first occurence, validation is second occurence\n")

for myFeature in feature_list:
    print(features[myFeature].describe())
    print
    print(features2[myFeature].describe())
    print
# Out:
# Training dataset is first occurence, validation is second occurence
#
# count    53702.000000
# mean         6.647807
# std          2.925716
# min          0.000000
# 25%          5.116000
# 50%          6.250000
# 75%          7.992000
# max         22.093000
# Name: Pathogen_Ala, dtype: float64
#
# count    513.000000
# mean       5.516632
# std        2.992890
# min        0.000000
# 25%        2.381000
# 50%        5.172000
# 75%        6.912000
# max       16.456000
# Name: Pathogen_Ala, dtype: float64
#
# count    53702.000000
# mean         2.258981
# std          2.216174
# min          0.000000
# 25%          0.806000
# 50%          1.431000
# 75%          3.014000
# max         27.536000
# Name: Pathogen_Arg, dtype: float64
#
# count    513.000000
# mean       3.072491
# std        2.619231
# min        0.000000
# 25%        1.210000
# 50%        3.419000
# 75%        3.941000
# max       13.441000
# Name: Pathogen_Arg, dtype: float64
#
# count    53702.000000
# mean         5.152791
# std          2.076523
# min          0.000000
# 25%          3.821000
# 50%          4.918000
# 75%          6.275000
# max         19.718000
# Name: Pathogen_Asn, dtype: float64
#
# count    513.000000
# mean       5.153827
# std        1.888793
# min        0.000000
# 25%        4.434000
# 50%        5.357000
# 75%        5.556000
# max       14.966000
# Name: Pathogen_Asn, dtype: float64
#
# count    53702.000000
# mean         6.520125
# std          2.689050
# min          0.000000
# 25%          4.969000
# 50%          6.452000
# 75%          7.798000
# max         22.613000
# Name: Pathogen_Asp, dtype: float64
#
# count    513.000000
# mean       5.907749
# std        2.740922
# min        0.000000
# 25%        4.762000
# 50%        5.640000
# 75%        6.667000
# max       24.490000
# Name: Pathogen_Asp, dtype: float64
#
# count    53702.000000
# mean         3.650372
# std          1.816506
# min          0.000000
# 25%          2.663000
# 50%          3.532000
# 75%          4.372000
# max         15.909000
# Name: Pathogen_Cys, dtype: float64
#
# count    513.000000
# mean       3.605667
# std        1.511978
# min        0.000000
# 25%        2.841000
# 50%        3.571000
# 75%        4.187000
# max       12.121000
# Name: Pathogen_Cys, dtype: float64
#
# count    53702.000000
# mean         6.739650
# std          3.450769
# min          0.000000
# 25%          5.102000
# 50%          6.324000
# 75%          7.759000
# max         39.158000
# Name: Pathogen_Gln, dtype: float64
#
# count    513.000000
# mean       7.918138
# std        2.791806
# min        2.083000
# 25%        6.410000
# 50%        8.287000
# 75%        9.524000
# max       39.158000
# Name: Pathogen_Gln, dtype: float64
#
# count    53702.000000
# mean         2.193963
# std          1.251295
# min          0.000000
# 25%          1.318000
# 50%          1.984000
# 75%          2.643000
# max          8.579000
# Name: Pathogen_Glu, dtype: float64
#
# count    513.000000
# mean       2.530380
# std        1.173495
# min        0.000000
# 25%        1.923000
# 50%        2.332000
# 75%        3.571000
# max       10.000000
# Name: Pathogen_Glu, dtype: float64
#
# count    53702.000000
# mean         5.601405
# std          2.523194
# min          0.000000
# 25%          4.310000
# 50%          5.652000
# 75%          6.957000
# max         20.388000
# Name: Pathogen_Gly, dtype: float64
#
# count    513.000000
# mean       4.863996
# std        1.941962
# min        0.000000
# 25%        4.167000
# 50%        4.187000
# 75%        5.590000
# max       15.789000
# Name: Pathogen_Gly, dtype: float64
#
# count    53702.000000
# mean         5.031414
# std          2.585231
# min          0.000000
# 25%          3.571000
# 50%          5.159000
# 75%          6.575000
# max         28.000000
# Name: Pathogen_His, dtype: float64
#
# count    513.000000
# mean       6.501889
# std        3.369669
# min        0.000000
# 25%        4.680000
# 50%        6.548000
# 75%        7.438000
# max       21.212000
# Name: Pathogen_His, dtype: float64
#
# count    53702.000000
# mean         9.807806
# std          3.627734
# min          1.266000
# 25%          7.538000
# 50%          9.559000
# 75%         11.207000
# max         34.091000
# Name: Pathogen_Ile, dtype: float64
#
# count    513.000000
# mean       8.876673
# std        2.395641
# min        0.000000
# 25%        7.660000
# 50%        9.506000
# 75%        9.606000
# max       18.913000
# Name: Pathogen_Ile, dtype: float64
#
# count    53702.000000
# mean         2.775806
# std          1.500492
# min          0.103000
# 25%          1.667000
# 50%          2.381000
# 75%          3.913000
# max         13.924000
# Name: Pathogen_Leu, dtype: float64
#
# count    513.000000
# mean       1.791538
# std        1.416989
# min        0.000000
# 25%        0.901000
# 50%        1.408000
# 75%        2.439000
# max       10.127000
# Name: Pathogen_Leu, dtype: float64
#
# count    53702.000000
# mean         4.183669
# std          1.987554
# min          0.000000
# 25%          2.965000
# 50%          3.968000
# 75%          5.172000
# max         23.529000
# Name: Pathogen_Lys, dtype: float64
#
# count    513.000000
# mean       4.274914
# std        1.847016
# min        0.000000
# 25%        2.976000
# 50%        3.687000
# 75%        5.473000
# max       11.475000
# Name: Pathogen_Lys, dtype: float64
#
# count    53702.000000
# mean         5.287491
# std          3.325767
# min          0.000000
# 25%          3.586000
# 50%          4.430000
# 75%          6.122000
# max         27.721000
# Name: Pathogen_Met, dtype: float64
#
# count    513.000000
# mean       5.891370
# std        2.845493
# min        0.000000
# 25%        4.132000
# 50%        4.869000
# 75%        8.333000
# max       27.721000
# Name: Pathogen_Met, dtype: float64
#
# count    53702.00000
# mean         4.21768
# std          1.99699
# min          0.00000
# 25%          3.00000
# 50%          3.87900
# 75%          5.08500
# max         24.30700
# Name: Pathogen_Phe, dtype: float64
#
# count    513.000000
# mean       3.315513
# std        1.864435
# min        0.000000
# 25%        2.265000
# 50%        2.479000
# 75%        4.062000
# max       11.494000
# Name: Pathogen_Phe, dtype: float64
#
# count    53702.000000
# mean         6.382676
# std          3.202320
# min          0.000000
# 25%          4.061000
# 50%          6.073000
# 75%          7.955000
# max         40.000000
# Name: Pathogen_Pro, dtype: float64
#
# count    513.000000
# mean       5.747246
# std        2.237365
# min        0.000000
# 25%        4.301000
# 50%        5.172000
# 75%        7.738000
# max       17.143000
# Name: Pathogen_Pro, dtype: float64
#
# count    53702.000000
# mean         6.919072
# std          2.331097
# min          0.000000
# 25%          5.342000
# 50%          6.851000
# 75%          8.233000
# max         30.851000
# Name: Pathogen_Ser, dtype: float64
#
# count    513.000000
# mean       5.607058
# std        2.278454
# min        0.000000
# 25%        4.167000
# 50%        5.051000
# 75%        6.920000
# max       20.000000
# Name: Pathogen_Ser, dtype: float64
#
# count    53702.000000
# mean         5.882705
# std          2.039819
# min          0.000000
# 25%          4.651000
# 50%          5.696000
# 75%          6.983000
# max         29.290000
# Name: Pathogen_Thr, dtype: float64
#
# count    513.000000
# mean       6.981530
# std        2.073373
# min        0.000000
# 25%        5.785000
# 50%        7.143000
# 75%        8.197000
# max       13.559000
# Name: Pathogen_Thr, dtype: float64
#
# count    53702.000000
# mean         6.481256
# std          2.307327
# min          0.000000
# 25%          5.000000
# 50%          6.186000
# 75%          7.510000
# max         19.298000
# Name: Pathogen_Trp, dtype: float64
#
# count    513.000000
# mean       6.897177
# std        1.797366
# min        1.389000
# 25%        5.983000
# 50%        7.143000
# 75%        7.826000
# max       14.667000
# Name: Pathogen_Trp, dtype: float64
#
# count    53702.000000
# mean         1.409117
# std          1.024709
# min          0.000000
# 25%          0.662000
# 50%          1.318000
# 75%          1.947000
# max          6.383000
# Name: Pathogen_Tyr, dtype: float64
#
# count    513.000000
# mean       1.497409
# std        0.958716
# min        0.000000
# 25%        1.010000
# 50%        1.205000
# 75%        1.970000
# max        6.667000
# Name: Pathogen_Tyr, dtype: float64
#
# count    53702.000000
# mean         2.856103
# std          1.546931
# min          0.000000
# 25%          1.984000
# 50%          2.744000
# 75%          3.696000
# max         14.583000
# Name: Pathogen_Val, dtype: float64
#
# count    513.000000
# mean       4.041515
# std        1.521562
# min        0.000000
# 25%        2.970000
# 50%        4.265000
# 75%        5.357000
# max       10.526000
# Name: Pathogen_Val, dtype: float64
#
# count    53702.000000
# mean         7.160959
# std          2.830639
# min          0.000000
# 25%          5.294000
# 50%          6.845000
# 75%          8.667000
# max         30.723000
# Name: Host_Ala, dtype: float64
#
# count    513.000000
# mean       6.812975
# std        2.686890
# min        0.000000
# 25%        5.042000
# 50%        6.490000
# 75%        8.153000
# max       17.647000
# Name: Host_Ala, dtype: float64
#
# count    53702.000000
# mean         2.505596
# std          2.644601
# min          0.000000
# 25%          1.015000
# 50%          1.823000
# 75%          3.010000
# max         41.494000
# Name: Host_Arg, dtype: float64
#
# count    513.000000
# mean       1.772990
# std        1.253091
# min        0.000000
# 25%        1.105000
# 50%        1.681000
# 75%        2.140000
# max       10.314000
# Name: Host_Arg, dtype: float64
#
# count    53702.000000
# mean         4.842435
# std          2.083732
# min          0.000000
# 25%          3.652000
# 50%          4.789000
# 75%          5.897000
# max         30.000000
# Name: Host_Asn, dtype: float64
#
# count    513.000000
# mean       5.001554
# std        1.719103
# min        0.000000
# 25%        3.896000
# 50%        5.034000
# 75%        5.882000
# max       14.800000
# Name: Host_Asn, dtype: float64
#
# count    53702.000000
# mean         6.817341
# std          2.937572
# min          0.000000
# 25%          4.981000
# 50%          6.612000
# 75%          8.253000
# max         37.857000
# Name: Host_Asp, dtype: float64
#
# count    513.000000
# mean       6.459721
# std        2.531820
# min        0.000000
# 25%        5.018000
# 50%        6.604000
# 75%        7.601000
# max       22.400000
# Name: Host_Asp, dtype: float64
#
# count    53702.000000
# mean         3.698818
# std          1.762159
# min          0.000000
# 25%          2.577000
# 50%          3.502000
# 75%          4.651000
# max         37.500000
# Name: Host_Cys, dtype: float64
#
# count    513.000000
# mean       3.615869
# std        1.394026
# min        0.510000
# 25%        2.724000
# 50%        3.662000
# 75%        4.202000
# max       11.111000
# Name: Host_Cys, dtype: float64
#
# count    53702.000000
# mean         6.897813
# std          3.558526
# min          0.000000
# 25%          4.854000
# 50%          6.410000
# 75%          8.166000
# max         43.210000
# Name: Host_Gln, dtype: float64
#
# count    513.000000
# mean       6.810080
# std        3.275011
# min        1.163000
# 25%        4.412000
# 50%        6.647000
# 75%        8.517000
# max       27.303000
# Name: Host_Gln, dtype: float64
#
# count    53702.000000
# mean         2.380243
# std          1.384242
# min          0.000000
# 25%          1.538000
# 50%          2.255000
# 75%          3.012000
# max         33.333000
# Name: Host_Glu, dtype: float64
#
# count    513.000000
# mean       2.363333
# std        1.170741
# min        0.000000
# 25%        1.572000
# 50%        2.308000
# 75%        3.361000
# max        6.630000
# Name: Host_Glu, dtype: float64
#
# count    53702.000000
# mean         4.421593
# std          2.135307
# min          0.000000
# 25%          2.915000
# 50%          4.314000
# 75%          5.719000
# max         20.588000
# Name: Host_Gly, dtype: float64
#
# count    513.000000
# mean       4.636637
# std        1.882743
# min        0.000000
# 25%        3.333000
# 50%        4.575000
# 75%        5.882000
# max       11.947000
# Name: Host_Gly, dtype: float64
#
# count    53702.000000
# mean         6.148151
# std          3.094400
# min          0.000000
# 25%          4.132000
# 50%          5.844000
# 75%          7.800000
# max         36.364000
# Name: Host_His, dtype: float64
#
# count    513.000000
# mean       6.536784
# std        2.923102
# min        0.000000
# 25%        4.688000
# 50%        6.406000
# 75%        7.576000
# max       21.600000
# Name: Host_His, dtype: float64
#
# count    53702.000000
# mean         9.865252
# std          3.323401
# min          0.000000
# 25%          7.719000
# 50%          9.733500
# 75%         11.828000
# max         29.630000
# Name: Host_Ile, dtype: float64
#
# count    513.000000
# mean       9.429400
# std        2.773496
# min        1.235000
# 25%        7.198000
# 50%        9.477000
# 75%       10.924000
# max       17.699000
# Name: Host_Ile, dtype: float64
# count    53702.000000
# mean         2.330362
# std          1.219062
# min          0.000000
# 25%          1.545000
# 50%          2.195000
# 75%          2.927000
# max         25.000000
# Name: Host_Leu, dtype: float64
#
# count    513.000000
# mean       2.299041
# std        1.251721
# min        0.000000
# 25%        1.577000
# 50%        2.024000
# 75%        2.789000
# max        9.268000
# Name: Host_Leu, dtype: float64
#
# count    53702.000000
# mean         3.659129
# std          1.675522
# min          0.000000
# 25%          2.582250
# 50%          3.571000
# 75%          4.641750
# max         30.000000
# Name: Host_Lys, dtype: float64
#
# count    513.000000
# mean       3.842404
# std        1.533840
# min        0.000000
# 25%        2.927000
# 50%        3.810000
# 75%        4.416000
# max       11.111000
# Name: Host_Lys, dtype: float64
#
# count    53702.000000
# mean         5.890446
# std          3.263302
# min          0.000000
# 25%          3.942000
# 50%          5.263000
# 75%          7.153500
# max         60.799000
# Name: Host_Met, dtype: float64
#
# count    513.000000
# mean       5.593852
# std        2.610184
# min        0.000000
# 25%        4.054000
# 50%        4.800000
# 75%        7.042000
# max       18.157000
# Name: Host_Met, dtype: float64
#
# count    53702.000000
# mean         4.646155
# std          2.142592
# min          0.000000
# 25%          3.334500
# 50%          4.422000
# 75%          5.613750
# max         33.333000
# Name: Host_Phe, dtype: float64
#
# count    513.000000
# mean       4.412649
# std        1.769991
# min        0.512000
# 25%        3.030000
# 50%        4.310000
# 75%        5.385000
# max       11.338000
# Name: Host_Phe, dtype: float64
#
# count    53702.000000
# mean         5.783765
# std          3.249401
# min          0.000000
# 25%          4.110000
# 50%          5.291000
# 75%          6.870000
# max         65.517000
# Name: Host_Pro, dtype: float64
#
# count    513.000000
# mean       5.355700
# std        2.328052
# min        0.000000
# 25%        3.846000
# 50%        5.042000
# 75%        6.161000
# max       17.241000
# Name: Host_Pro, dtype: float64
#
# count    53702.000000
# mean         7.546631
# std          2.812129
# min          0.000000
# 25%          5.751000
# 50%          7.237000
# 75%          9.012750
# max         41.660000
# Name: Host_Ser, dtype: float64
#
# count    513.000000
# mean       8.061943
# std        3.193158
# min        0.752000
# 25%        5.729000
# 50%        7.345000
# 75%       10.514000
# max       16.964000
# Name: Host_Ser, dtype: float64
#
# count    53702.000000
# mean         5.244652
# std          1.903987
# min          0.000000
# 25%          4.118000
# 50%          5.128000
# 75%          6.213000
# max         33.559000
# Name: Host_Thr, dtype: float64
#
# count    513.000000
# mean       5.702877
# std        2.116383
# min        0.000000
# 25%        4.202000
# 50%        5.298000
# 75%        6.897000
# max       11.857000
# Name: Host_Thr, dtype: float64
#
# count    53702.000000
# mean         6.126823
# std          2.037701
# min          0.000000
# 25%          4.885000
# 50%          6.024000
# 75%          7.303750
# max         37.143000
# Name: Host_Trp, dtype: float64
#
# count    513.000000
# mean       6.540645
# std        1.955991
# min        0.000000
# 25%        5.357000
# 50%        6.548000
# 75%        7.563000
# max       12.925000
# Name: Host_Trp, dtype: float64
#
# count    53702.000000
# mean         1.174871
# std          0.982874
# min          0.000000
# 25%          0.488000
# 50%          0.992000
# 75%          1.661000
# max         12.500000
# Name: Host_Tyr, dtype: float64
#
# count    513.000000
# mean       1.300889
# std        0.935470
# min        0.000000
# 25%        0.676000
# 50%        1.227000
# 75%        1.681000
# max        9.836000
# Name: Host_Tyr, dtype: float64
#
# count    53702.000000
# mean         2.833782
# std          1.601521
# min          0.000000
# 25%          1.773000
# 50%          2.655000
# 75%          3.672000
# max         26.250000
# Name: Host_Val, dtype: float64
#
# count    513.000000
# mean       3.434583
# std        1.679392
# min        0.000000
# 25%        2.143000
# 50%        3.214000
# 75%        5.042000
# max        8.333000
# Name: Host_Val, dtype: float64
#
# count    53702.000000
# mean         0.045126
# std          0.049008
# min          0.000000
# 25%          0.010000
# 50%          0.025000
# 75%          0.070000
# max          0.480000
# Name: GO_Similarity_Score, dtype: float64
#
# count    513.000000
# mean       0.059303
# std        0.072894
# min        0.000000
# 25%        0.010000
# 50%        0.030000
# 75%        0.080000
# max        0.437500
# Name: GO_Similarity_Score, dtype: float64
